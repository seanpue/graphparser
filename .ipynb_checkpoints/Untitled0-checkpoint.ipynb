# %%
import graphparser
reload(graphparser)
nagarip = graphparser.GraphParser('settings/devanagari.yaml')

# %%
nagarip.token_set
# Out:
# {'\x00',
#  '\n',
#  ' ',
#  '!',
#  "'",
#  '(',
#  '((',
#  '(-e)',
#  ')',
#  '))',
#  ',',
#  '-',
#  '--',
#  '----',
#  '-e',
#  '.r',
#  '.s',
#  '.z',
#  '/',
#  ':',
#  ':n',
#  ':t',
#  ':z',
#  ';',
#  ';aa',
#  ';d',
#  ';dh',
#  ';e',
#  ';g',
#  ';h',
#  ';m',
#  ';n',
#  ';o',
#  ';r',
#  ';rh',
#  ';s',
#  ';t',
#  ';th',
#  ';x',
#  ';z',
#  '?',
#  '[',
#  ']',
#  '_',
#  'a',
#  'aa',
#  'ai',
#  'au',
#  'b',
#  'bh',
#  'ch',
#  'chh',
#  'd',
#  'dh',
#  'e',
#  'f',
#  'g',
#  'gh',
#  'h',
#  'i',
#  'ii',
#  'j',
#  'jh',
#  'k',
#  'kh',
#  'l',
#  'm',
#  'n',
#  'o',
#  'p',
#  'ph',
#  'q',
#  'r',
#  's',
#  'sh',
#  't',
#  'th',
#  'u',
#  'uu',
#  'v',
#  'w',
#  'y',
#  'z',
#  'zh',
#  '|'}

# %%
nagarip.onmatch_rules[0]
# Out:
# ((['z_consonant'], ['z_consonant']), u'\u094d')

# %%
len(nagarip.onmatch_rules)
# Out:
# 44

# %%
nagarip.tokens
# Out:
# {'\x00': ['wb'],
#  '\n': ['wb'],
#  ' ': ['wb'],
#  '!': ['punctuation', 'wb'],
#  "'": ['letter_break'],
#  '(': ['punctuation', 'wb'],
#  '((': ['ain', 'consonant'],
#  '(-e)': ['hidden_izaafat'],
#  ')': ['punctuation', 'wb'],
#  '))': ['vowel'],
#  ',': ['punctuation', 'wb'],
#  '-': ['wb'],
#  '--': ['punctuation', 'wb'],
#  '----': ['punctuation', 'wb'],
#  '-e': ['izaafat'],
#  '.r': ['consonant'],
#  '.s': ['consonant'],
#  '.z': ['consonant', 'z_consonant'],
#  '/': ['wb'],
#  ':': ['punctuation', 'wb'],
#  ':n': ['consonant'],
#  ':t': ['consonant'],
#  ':z': ['consonant', 'z_consonant'],
#  ';': ['punctuation', 'wb'],
#  ';aa': ['vowel', 'long_vowel'],
#  ';d': ['consonant'],
#  ';dh': ['consonant'],
#  ';e': ['vowel', 'short_vowel', 'short_vowel_e'],
#  ';g': ['consonant'],
#  ';h': ['consonant', 'h_char'],
#  ';m': ['vowel_nasal'],
#  ';n': ['vowel_nasal'],
#  ';o': ['vowel'],
#  ';r': ['consonant'],
#  ';rh': ['consonant'],
#  ';s': ['consonant'],
#  ';t': ['consonant', ';t'],
#  ';th': ['consonant', ';th'],
#  ';x': [';x_class', 'consonant'],
#  ';z': ['consonant', 'z_consonant'],
#  '?': ['punctuation', 'wb'],
#  '[': ['punctuation', 'wb'],
#  ']': ['punctuation', 'wb'],
#  '_': ['under_score'],
#  'a': ['short_vowel', 'short_vowel_a', 'vowel', 'a'],
#  'aa': ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel'],
#  'ai': ['long_vowel', 'vowel'],
#  'au': ['long_vowel', 'vowel'],
#  'b': ['consonant'],
#  'bh': ['consonant'],
#  'ch': ['consonant', 'ch'],
#  'chh': ['consonant', 'ch_group'],
#  'd': ['consonant', 'd'],
#  'dh': ['consonant'],
#  'e': ['long_vowel', 'e', 'vowel'],
#  'f': ['consonant'],
#  'g': ['consonant'],
#  'gh': ['consonant'],
#  'h': ['consonant', 'consonant_h', 'h', 'h_char'],
#  'i': ['short_vowel', 'vowel'],
#  'ii': ['long_vowel', 'vowel', 'ii'],
#  'j': ['consonant'],
#  'jh': ['consonant'],
#  'k': ['consonant', 'k', 'k_group'],
#  'kh': ['consonant', 'k_group', 'kh'],
#  'l': ['consonant'],
#  'm': ['consonant', 'm'],
#  'n': ['consonant', 'n'],
#  'o': ['vowel', 'long_vowel'],
#  'p': ['consonant'],
#  'ph': ['consonant'],
#  'q': ['consonant'],
#  'r': ['consonant', 'r'],
#  's': ['consonant', 'sibilant', 's'],
#  'sh': ['consonant', 'sibilant'],
#  't': ['consonant', 't'],
#  'th': ['consonant'],
#  'u': ['short_vowel', 'vowel'],
#  'uu': ['vowel', 'long_vowel', 'candrabindu_vowel'],
#  'v': ['consonant', 'v'],
#  'w': ['consonant'],
#  'y': ['consonant'],
#  'z': ['consonant', 'z', 'z_consonant'],
#  'zh': ['consonant'],
#  '|': ['hindi_break']}

# %%
tokens
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c630824e7e67> in <module>()
# ----> 1 tokens
#
# NameError: name 'tokens' is not defined

# %%
from collections import defaultdict
t_om = defaultdict(list)
for t,t_classes in nagarip.tokens.iteritems():
    for o in nagarip.onmatch_rules:
        match_rules,prod = o
        curr_class=match_rules[1]
        if curr_class in t_classes:
            t_om[t].append(o)
# Out:
# ['z_consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['h_char'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# [] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['kh'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['r'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['z'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['h'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['v'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# [';th'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['d'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['z', 'short_vowel', 'consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['k_group'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['ch_group'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['n', 'aa', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['n', 'e', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'aa', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'e', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'ii', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['ain', 'short_vowel', 'wb'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['alef', 'aa', 'vowel', 'long_vowel', 'candrabindu_vowel']
# ['z_consonant'] ['consonant', 'ch']
# ['h_char'] ['consonant', 'ch']
# [] ['consonant', 'ch']
# ['kh'] ['consonant', 'ch']
# ['r'] ['consonant', 'ch']
# ['z'] ['consonant', 'ch']
# ['h'] ['consonant', 'ch']
# ['v'] ['consonant', 'ch']
# [';th'] ['consonant', 'ch']
# ['d'] ['consonant', 'ch']
# ['t', 'long_vowel'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'ch']
# ['consonant', 'short_vowel'] ['consonant', 'ch']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant', 'vowel'] ['consonant', 'ch']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'ch']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['k_group'] ['consonant', 'ch']
# ['ch_group'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch']
# ['consonant', 'wb'] ['consonant', 'ch']
# ['consonant', 'wb'] ['consonant', 'ch']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'ch']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'ch']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['n', 'aa', 'wb'] ['consonant', 'ch']
# ['n', 'e', 'wb'] ['consonant', 'ch']
# ['t', 'aa', 'wb'] ['consonant', 'ch']
# ['t', 'e', 'wb'] ['consonant', 'ch']
# ['t', 'ii', 'wb'] ['consonant', 'ch']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant', 'long_vowel'] ['consonant', 'ch']
# ['consonant'] ['consonant', 'ch']
# ['z_consonant'] ['wb']
# ['h_char'] ['wb']
# [] ['wb']
# ['kh'] ['wb']
# ['r'] ['wb']
# ['z'] ['wb']
# ['h'] ['wb']
# ['v'] ['wb']
# [';th'] ['wb']
# ['d'] ['wb']
# ['t', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['wb']
# ['consonant', 'short_vowel'] ['wb']
# ['consonant', 'long_vowel', 'consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'vowel'] ['wb']
# ['z', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['k_group'] ['wb']
# ['ch_group'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['n', 'aa', 'wb'] ['wb']
# ['n', 'e', 'wb'] ['wb']
# ['t', 'aa', 'wb'] ['wb']
# ['t', 'e', 'wb'] ['wb']
# ['t', 'ii', 'wb'] ['wb']
# ['ain', 'short_vowel', 'wb'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['z_consonant'] ['wb']
# ['h_char'] ['wb']
# [] ['wb']
# ['kh'] ['wb']
# ['r'] ['wb']
# ['z'] ['wb']
# ['h'] ['wb']
# ['v'] ['wb']
# [';th'] ['wb']
# ['d'] ['wb']
# ['t', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['wb']
# ['consonant', 'short_vowel'] ['wb']
# ['consonant', 'long_vowel', 'consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'vowel'] ['wb']
# ['z', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['k_group'] ['wb']
# ['ch_group'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['n', 'aa', 'wb'] ['wb']
# ['n', 'e', 'wb'] ['wb']
# ['t', 'aa', 'wb'] ['wb']
# ['t', 'e', 'wb'] ['wb']
# ['t', 'ii', 'wb'] ['wb']
# ['ain', 'short_vowel', 'wb'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['z_consonant'] ['vowel']
# ['h_char'] ['vowel']
# [] ['vowel']
# ['kh'] ['vowel']
# ['r'] ['vowel']
# ['z'] ['vowel']
# ['h'] ['vowel']
# ['v'] ['vowel']
# [';th'] ['vowel']
# ['d'] ['vowel']
# ['t', 'long_vowel'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant'] ['vowel']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['vowel']
# ['consonant', 'short_vowel'] ['vowel']
# ['consonant', 'long_vowel', 'consonant'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant', 'vowel'] ['vowel']
# ['z', 'short_vowel', 'consonant'] ['vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel']
# ['consonant'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant'] ['vowel']
# ['k_group'] ['vowel']
# ['ch_group'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel']
# ['consonant', 'wb'] ['vowel']
# ['consonant', 'wb'] ['vowel']
# ['consonant', 'long_vowel', 'wb'] ['vowel']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel']
# ['consonant'] ['vowel']
# ['n', 'aa', 'wb'] ['vowel']
# ['n', 'e', 'wb'] ['vowel']
# ['t', 'aa', 'wb'] ['vowel']
# ['t', 'e', 'wb'] ['vowel']
# ['t', 'ii', 'wb'] ['vowel']
# ['ain', 'short_vowel', 'wb'] ['vowel']
# ['consonant'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant', 'long_vowel'] ['vowel']
# ['consonant'] ['vowel']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['izaafat']
# ['h_char'] ['izaafat']
# [] ['izaafat']
# ['kh'] ['izaafat']
# ['r'] ['izaafat']
# ['z'] ['izaafat']
# ['h'] ['izaafat']
# ['v'] ['izaafat']
# [';th'] ['izaafat']
# ['d'] ['izaafat']
# ['t', 'long_vowel'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant'] ['izaafat']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['izaafat']
# ['consonant', 'short_vowel'] ['izaafat']
# ['consonant', 'long_vowel', 'consonant'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant', 'vowel'] ['izaafat']
# ['z', 'short_vowel', 'consonant'] ['izaafat']
# ['consonant', 'short_vowel', 'consonant'] ['izaafat']
# ['consonant'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant'] ['izaafat']
# ['k_group'] ['izaafat']
# ['ch_group'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant', 'short_vowel', 'consonant'] ['izaafat']
# ['consonant', 'wb'] ['izaafat']
# ['consonant', 'wb'] ['izaafat']
# ['consonant', 'long_vowel', 'wb'] ['izaafat']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['izaafat']
# ['consonant', 'short_vowel', 'consonant'] ['izaafat']
# ['consonant'] ['izaafat']
# ['n', 'aa', 'wb'] ['izaafat']
# ['n', 'e', 'wb'] ['izaafat']
# ['t', 'aa', 'wb'] ['izaafat']
# ['t', 'e', 'wb'] ['izaafat']
# ['t', 'ii', 'wb'] ['izaafat']
# ['ain', 'short_vowel', 'wb'] ['izaafat']
# ['consonant'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant', 'long_vowel'] ['izaafat']
# ['consonant'] ['izaafat']
# ['z_consonant'] ['wb']
# ['h_char'] ['wb']
# [] ['wb']
# ['kh'] ['wb']
# ['r'] ['wb']
# ['z'] ['wb']
# ['h'] ['wb']
# ['v'] ['wb']
# [';th'] ['wb']
# ['d'] ['wb']
# ['t', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['wb']
# ['consonant', 'short_vowel'] ['wb']
# ['consonant', 'long_vowel', 'consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'vowel'] ['wb']
# ['z', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['k_group'] ['wb']
# ['ch_group'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'wb'] ['wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['wb']
# ['consonant', 'short_vowel', 'consonant'] ['wb']
# ['consonant'] ['wb']
# ['n', 'aa', 'wb'] ['wb']
# ['n', 'e', 'wb'] ['wb']
# ['t', 'aa', 'wb'] ['wb']
# ['t', 'e', 'wb'] ['wb']
# ['t', 'ii', 'wb'] ['wb']
# ['ain', 'short_vowel', 'wb'] ['wb']
# ['consonant'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant', 'long_vowel'] ['wb']
# ['consonant'] ['wb']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant', 'ch_group']
# ['h_char'] ['consonant', 'ch_group']
# [] ['consonant', 'ch_group']
# ['kh'] ['consonant', 'ch_group']
# ['r'] ['consonant', 'ch_group']
# ['z'] ['consonant', 'ch_group']
# ['h'] ['consonant', 'ch_group']
# ['v'] ['consonant', 'ch_group']
# [';th'] ['consonant', 'ch_group']
# ['d'] ['consonant', 'ch_group']
# ['t', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'ch_group']
# ['consonant', 'short_vowel'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant', 'vowel'] ['consonant', 'ch_group']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'ch_group']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['k_group'] ['consonant', 'ch_group']
# ['ch_group'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch_group']
# ['consonant', 'wb'] ['consonant', 'ch_group']
# ['consonant', 'wb'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'ch_group']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['n', 'aa', 'wb'] ['consonant', 'ch_group']
# ['n', 'e', 'wb'] ['consonant', 'ch_group']
# ['t', 'aa', 'wb'] ['consonant', 'ch_group']
# ['t', 'e', 'wb'] ['consonant', 'ch_group']
# ['t', 'ii', 'wb'] ['consonant', 'ch_group']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant', 'long_vowel'] ['consonant', 'ch_group']
# ['consonant'] ['consonant', 'ch_group']
# ['z_consonant'] ['punctuation', 'wb']
# ['h_char'] ['punctuation', 'wb']
# [] ['punctuation', 'wb']
# ['kh'] ['punctuation', 'wb']
# ['r'] ['punctuation', 'wb']
# ['z'] ['punctuation', 'wb']
# ['h'] ['punctuation', 'wb']
# ['v'] ['punctuation', 'wb']
# [';th'] ['punctuation', 'wb']
# ['d'] ['punctuation', 'wb']
# ['t', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['punctuation', 'wb']
# ['consonant', 'short_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'vowel'] ['punctuation', 'wb']
# ['z', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['k_group'] ['punctuation', 'wb']
# ['ch_group'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['n', 'aa', 'wb'] ['punctuation', 'wb']
# ['n', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'aa', 'wb'] ['punctuation', 'wb']
# ['t', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'ii', 'wb'] ['punctuation', 'wb']
# ['ain', 'short_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['z_consonant'] ['punctuation', 'wb']
# ['h_char'] ['punctuation', 'wb']
# [] ['punctuation', 'wb']
# ['kh'] ['punctuation', 'wb']
# ['r'] ['punctuation', 'wb']
# ['z'] ['punctuation', 'wb']
# ['h'] ['punctuation', 'wb']
# ['v'] ['punctuation', 'wb']
# [';th'] ['punctuation', 'wb']
# ['d'] ['punctuation', 'wb']
# ['t', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['punctuation', 'wb']
# ['consonant', 'short_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'vowel'] ['punctuation', 'wb']
# ['z', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['k_group'] ['punctuation', 'wb']
# ['ch_group'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['n', 'aa', 'wb'] ['punctuation', 'wb']
# ['n', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'aa', 'wb'] ['punctuation', 'wb']
# ['t', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'ii', 'wb'] ['punctuation', 'wb']
# ['ain', 'short_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['punctuation', 'wb']
# ['h_char'] ['punctuation', 'wb']
# [] ['punctuation', 'wb']
# ['kh'] ['punctuation', 'wb']
# ['r'] ['punctuation', 'wb']
# ['z'] ['punctuation', 'wb']
# ['h'] ['punctuation', 'wb']
# ['v'] ['punctuation', 'wb']
# [';th'] ['punctuation', 'wb']
# ['d'] ['punctuation', 'wb']
# ['t', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['punctuation', 'wb']
# ['consonant', 'short_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'vowel'] ['punctuation', 'wb']
# ['z', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['k_group'] ['punctuation', 'wb']
# ['ch_group'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['n', 'aa', 'wb'] ['punctuation', 'wb']
# ['n', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'aa', 'wb'] ['punctuation', 'wb']
# ['t', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'ii', 'wb'] ['punctuation', 'wb']
# ['ain', 'short_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['punctuation', 'wb']
# ['h_char'] ['punctuation', 'wb']
# [] ['punctuation', 'wb']
# ['kh'] ['punctuation', 'wb']
# ['r'] ['punctuation', 'wb']
# ['z'] ['punctuation', 'wb']
# ['h'] ['punctuation', 'wb']
# ['v'] ['punctuation', 'wb']
# [';th'] ['punctuation', 'wb']
# ['d'] ['punctuation', 'wb']
# ['t', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['punctuation', 'wb']
# ['consonant', 'short_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'vowel'] ['punctuation', 'wb']
# ['z', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['k_group'] ['punctuation', 'wb']
# ['ch_group'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['punctuation', 'wb']
# ['consonant', 'short_vowel', 'consonant'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['n', 'aa', 'wb'] ['punctuation', 'wb']
# ['n', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'aa', 'wb'] ['punctuation', 'wb']
# ['t', 'e', 'wb'] ['punctuation', 'wb']
# ['t', 'ii', 'wb'] ['punctuation', 'wb']
# ['ain', 'short_vowel', 'wb'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant', 'long_vowel'] ['punctuation', 'wb']
# ['consonant'] ['punctuation', 'wb']
# ['z_consonant'] ['ain', 'consonant']
# ['h_char'] ['ain', 'consonant']
# [] ['ain', 'consonant']
# ['kh'] ['ain', 'consonant']
# ['r'] ['ain', 'consonant']
# ['z'] ['ain', 'consonant']
# ['h'] ['ain', 'consonant']
# ['v'] ['ain', 'consonant']
# [';th'] ['ain', 'consonant']
# ['d'] ['ain', 'consonant']
# ['t', 'long_vowel'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['ain', 'consonant']
# ['consonant', 'short_vowel'] ['ain', 'consonant']
# ['consonant', 'long_vowel', 'consonant'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant', 'vowel'] ['ain', 'consonant']
# ['z', 'short_vowel', 'consonant'] ['ain', 'consonant']
# ['consonant', 'short_vowel', 'consonant'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['k_group'] ['ain', 'consonant']
# ['ch_group'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant', 'short_vowel', 'consonant'] ['ain', 'consonant']
# ['consonant', 'wb'] ['ain', 'consonant']
# ['consonant', 'wb'] ['ain', 'consonant']
# ['consonant', 'long_vowel', 'wb'] ['ain', 'consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['ain', 'consonant']
# ['consonant', 'short_vowel', 'consonant'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['n', 'aa', 'wb'] ['ain', 'consonant']
# ['n', 'e', 'wb'] ['ain', 'consonant']
# ['t', 'aa', 'wb'] ['ain', 'consonant']
# ['t', 'e', 'wb'] ['ain', 'consonant']
# ['t', 'ii', 'wb'] ['ain', 'consonant']
# ['ain', 'short_vowel', 'wb'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant', 'long_vowel'] ['ain', 'consonant']
# ['consonant'] ['ain', 'consonant']
# ['z_consonant'] ['consonant', 'z_consonant']
# ['h_char'] ['consonant', 'z_consonant']
# [] ['consonant', 'z_consonant']
# ['kh'] ['consonant', 'z_consonant']
# ['r'] ['consonant', 'z_consonant']
# ['z'] ['consonant', 'z_consonant']
# ['h'] ['consonant', 'z_consonant']
# ['v'] ['consonant', 'z_consonant']
# [';th'] ['consonant', 'z_consonant']
# ['d'] ['consonant', 'z_consonant']
# ['t', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'z_consonant']
# ['consonant', 'short_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'vowel'] ['consonant', 'z_consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'z_consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['k_group'] ['consonant', 'z_consonant']
# ['ch_group'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'z_consonant']
# ['consonant', 'wb'] ['consonant', 'z_consonant']
# ['consonant', 'wb'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'z_consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['n', 'aa', 'wb'] ['consonant', 'z_consonant']
# ['n', 'e', 'wb'] ['consonant', 'z_consonant']
# ['t', 'aa', 'wb'] ['consonant', 'z_consonant']
# ['t', 'e', 'wb'] ['consonant', 'z_consonant']
# ['t', 'ii', 'wb'] ['consonant', 'z_consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant', 'long_vowel'] ['consonant', 'z_consonant']
# ['consonant'] ['consonant', 'z_consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant', 'd']
# ['h_char'] ['consonant', 'd']
# [] ['consonant', 'd']
# ['kh'] ['consonant', 'd']
# ['r'] ['consonant', 'd']
# ['z'] ['consonant', 'd']
# ['h'] ['consonant', 'd']
# ['v'] ['consonant', 'd']
# [';th'] ['consonant', 'd']
# ['d'] ['consonant', 'd']
# ['t', 'long_vowel'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'd']
# ['consonant', 'short_vowel'] ['consonant', 'd']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant', 'vowel'] ['consonant', 'd']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'd']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['k_group'] ['consonant', 'd']
# ['ch_group'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'd']
# ['consonant', 'wb'] ['consonant', 'd']
# ['consonant', 'wb'] ['consonant', 'd']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'd']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'd']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['n', 'aa', 'wb'] ['consonant', 'd']
# ['n', 'e', 'wb'] ['consonant', 'd']
# ['t', 'aa', 'wb'] ['consonant', 'd']
# ['t', 'e', 'wb'] ['consonant', 'd']
# ['t', 'ii', 'wb'] ['consonant', 'd']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant', 'long_vowel'] ['consonant', 'd']
# ['consonant'] ['consonant', 'd']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['h_char'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# [] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['kh'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['r'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['z'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['h'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['v'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# [';th'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['d'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['z', 'short_vowel', 'consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['k_group'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['ch_group'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['n', 'aa', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['n', 'e', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'aa', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'e', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['t', 'ii', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['ain', 'short_vowel', 'wb'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['consonant'] ['vowel', 'long_vowel', 'candrabindu_vowel']
# ['z_consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['h_char'] ['consonant', 'consonant_h', 'h', 'h_char']
# [] ['consonant', 'consonant_h', 'h', 'h_char']
# ['kh'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['r'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['z'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['h'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['v'] ['consonant', 'consonant_h', 'h', 'h_char']
# [';th'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['d'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['t', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'short_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['k_group'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['ch_group'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['n', 'aa', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['n', 'e', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['t', 'aa', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['t', 'e', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['t', 'ii', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant', 'long_vowel'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['consonant'] ['consonant', 'consonant_h', 'h', 'h_char']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ...
# ['consonant'] ['consonant', 'm']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'm']
# ['consonant', 'short_vowel'] ['consonant', 'm']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'm']
# ['consonant', 'long_vowel'] ['consonant', 'm']
# ['consonant', 'vowel'] ['consonant', 'm']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'm']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'm']
# ['consonant'] ['consonant', 'm']
# ['consonant', 'long_vowel'] ['consonant', 'm']
# ['consonant'] ['consonant', 'm']
# ['k_group'] ['consonant', 'm']
# ['ch_group'] ['consonant', 'm']
# ['consonant', 'long_vowel'] ['consonant', 'm']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'm']
# ['consonant', 'wb'] ['consonant', 'm']
# ['consonant', 'wb'] ['consonant', 'm']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'm']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'm']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'm']
# ['consonant'] ['consonant', 'm']
# ['n', 'aa', 'wb'] ['consonant', 'm']
# ['n', 'e', 'wb'] ['consonant', 'm']
# ['t', 'aa', 'wb'] ['consonant', 'm']
# ['t', 'e', 'wb'] ['consonant', 'm']
# ['t', 'ii', 'wb'] ['consonant', 'm']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'm']
# ['consonant'] ['consonant', 'm']
# ['consonant', 'long_vowel'] ['consonant', 'm']
# ['consonant', 'long_vowel'] ['consonant', 'm']
# ['consonant'] ['consonant', 'm']
# ['z_consonant'] ['vowel', 'long_vowel']
# ['h_char'] ['vowel', 'long_vowel']
# [] ['vowel', 'long_vowel']
# ['kh'] ['vowel', 'long_vowel']
# ['r'] ['vowel', 'long_vowel']
# ['z'] ['vowel', 'long_vowel']
# ['h'] ['vowel', 'long_vowel']
# ['v'] ['vowel', 'long_vowel']
# [';th'] ['vowel', 'long_vowel']
# ['d'] ['vowel', 'long_vowel']
# ['t', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['vowel', 'long_vowel']
# ['consonant', 'short_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel', 'consonant'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'vowel'] ['vowel', 'long_vowel']
# ['z', 'short_vowel', 'consonant'] ['vowel', 'long_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['k_group'] ['vowel', 'long_vowel']
# ['ch_group'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel']
# ['consonant', 'wb'] ['vowel', 'long_vowel']
# ['consonant', 'wb'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel', 'wb'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['vowel', 'long_vowel']
# ['consonant', 'short_vowel', 'consonant'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['n', 'aa', 'wb'] ['vowel', 'long_vowel']
# ['n', 'e', 'wb'] ['vowel', 'long_vowel']
# ['t', 'aa', 'wb'] ['vowel', 'long_vowel']
# ['t', 'e', 'wb'] ['vowel', 'long_vowel']
# ['t', 'ii', 'wb'] ['vowel', 'long_vowel']
# ['ain', 'short_vowel', 'wb'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant', 'long_vowel'] ['vowel', 'long_vowel']
# ['consonant'] ['vowel', 'long_vowel']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant', 'sibilant', 's']
# ['h_char'] ['consonant', 'sibilant', 's']
# [] ['consonant', 'sibilant', 's']
# ['kh'] ['consonant', 'sibilant', 's']
# ['r'] ['consonant', 'sibilant', 's']
# ['z'] ['consonant', 'sibilant', 's']
# ['h'] ['consonant', 'sibilant', 's']
# ['v'] ['consonant', 'sibilant', 's']
# [';th'] ['consonant', 'sibilant', 's']
# ['d'] ['consonant', 'sibilant', 's']
# ['t', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'sibilant', 's']
# ['consonant', 'short_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'vowel'] ['consonant', 'sibilant', 's']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['k_group'] ['consonant', 'sibilant', 's']
# ['ch_group'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'wb'] ['consonant', 'sibilant', 's']
# ['consonant', 'wb'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'sibilant', 's']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['n', 'aa', 'wb'] ['consonant', 'sibilant', 's']
# ['n', 'e', 'wb'] ['consonant', 'sibilant', 's']
# ['t', 'aa', 'wb'] ['consonant', 'sibilant', 's']
# ['t', 'e', 'wb'] ['consonant', 'sibilant', 's']
# ['t', 'ii', 'wb'] ['consonant', 'sibilant', 's']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant', 's']
# ['consonant'] ['consonant', 'sibilant', 's']
# ['z_consonant'] ['consonant', 'sibilant']
# ['h_char'] ['consonant', 'sibilant']
# [] ['consonant', 'sibilant']
# ['kh'] ['consonant', 'sibilant']
# ['r'] ['consonant', 'sibilant']
# ['z'] ['consonant', 'sibilant']
# ['h'] ['consonant', 'sibilant']
# ['v'] ['consonant', 'sibilant']
# [';th'] ['consonant', 'sibilant']
# ['d'] ['consonant', 'sibilant']
# ['t', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant', 'sibilant']
# ['consonant', 'short_vowel'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant', 'vowel'] ['consonant', 'sibilant']
# ['z', 'short_vowel', 'consonant'] ['consonant', 'sibilant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['k_group'] ['consonant', 'sibilant']
# ['ch_group'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant']
# ['consonant', 'wb'] ['consonant', 'sibilant']
# ['consonant', 'wb'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel', 'wb'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant', 'sibilant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['n', 'aa', 'wb'] ['consonant', 'sibilant']
# ['n', 'e', 'wb'] ['consonant', 'sibilant']
# ['t', 'aa', 'wb'] ['consonant', 'sibilant']
# ['t', 'e', 'wb'] ['consonant', 'sibilant']
# ['t', 'ii', 'wb'] ['consonant', 'sibilant']
# ['ain', 'short_vowel', 'wb'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant', 'long_vowel'] ['consonant', 'sibilant']
# ['consonant'] ['consonant', 'sibilant']
# ['z_consonant'] ['short_vowel', 'vowel']
# ['h_char'] ['short_vowel', 'vowel']
# [] ['short_vowel', 'vowel']
# ['kh'] ['short_vowel', 'vowel']
# ['r'] ['short_vowel', 'vowel']
# ['z'] ['short_vowel', 'vowel']
# ['h'] ['short_vowel', 'vowel']
# ['v'] ['short_vowel', 'vowel']
# [';th'] ['short_vowel', 'vowel']
# ['d'] ['short_vowel', 'vowel']
# ['t', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['short_vowel', 'vowel']
# ['consonant', 'short_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel', 'consonant'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'vowel'] ['short_vowel', 'vowel']
# ['z', 'short_vowel', 'consonant'] ['short_vowel', 'vowel']
# ['consonant', 'short_vowel', 'consonant'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['k_group'] ['short_vowel', 'vowel']
# ['ch_group'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'short_vowel', 'consonant'] ['short_vowel', 'vowel']
# ['consonant', 'wb'] ['short_vowel', 'vowel']
# ['consonant', 'wb'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel', 'wb'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['short_vowel', 'vowel']
# ['consonant', 'short_vowel', 'consonant'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['n', 'aa', 'wb'] ['short_vowel', 'vowel']
# ['n', 'e', 'wb'] ['short_vowel', 'vowel']
# ['t', 'aa', 'wb'] ['short_vowel', 'vowel']
# ['t', 'e', 'wb'] ['short_vowel', 'vowel']
# ['t', 'ii', 'wb'] ['short_vowel', 'vowel']
# ['ain', 'short_vowel', 'wb'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant', 'long_vowel'] ['short_vowel', 'vowel']
# ['consonant'] ['short_vowel', 'vowel']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['z_consonant'] ['consonant']
# ['h_char'] ['consonant']
# [] ['consonant']
# ['kh'] ['consonant']
# ['r'] ['consonant']
# ['z'] ['consonant']
# ['h'] ['consonant']
# ['v'] ['consonant']
# [';th'] ['consonant']
# ['d'] ['consonant']
# ['t', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel', 'vowel_nasal'] ['consonant']
# ['consonant', 'short_vowel'] ['consonant']
# ['consonant', 'long_vowel', 'consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'vowel'] ['consonant']
# ['z', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']
# ['k_group'] ['consonant']
# ['ch_group'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'wb'] ['consonant']
# ['consonant', 'long_vowel', 'consonant', 'wb'] ['consonant']
# ['consonant', 'short_vowel', 'consonant'] ['consonant']
# ['consonant'] ['consonant']
# ['n', 'aa', 'wb'] ['consonant']
# ['n', 'e', 'wb'] ['consonant']
# ['t', 'aa', 'wb'] ['consonant']
# ['t', 'e', 'wb'] ['consonant']
# ['t', 'ii', 'wb'] ['consonant']
# ['ain', 'short_vowel', 'wb'] ['consonant']
# ['consonant'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant', 'long_vowel'] ['consonant']
# ['consonant'] ['consonant']

# %%
t_om
# Out:
# defaultdict(<type 'list'>, {})
