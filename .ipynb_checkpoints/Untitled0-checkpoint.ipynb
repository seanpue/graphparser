# %%
import graphparser
reload(graphparser)
nagarip = graphparser.GraphParser('settings/devanagari.yaml')

# %%
print nagarip.parse("aap").output
# Out:
# ापाबाता क्या हैं

# %%
nagarip.old_parser.onmatch_rules
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-5617ece11e42> in <module>()
# ----> 1 nagarip.old_parser.onmatch_rules
#
# AttributeError: GraphParser instance has no attribute 'old_parser'

# %%
nagarip.sorted_out_edges
# Out:
# defaultdict(<type 'list'>, {0: [(0, 1, {'weight': 0}), (0, 130, {'weight': 0}), (0, 3, {'weight': 0}), (0, 223, {'weight': 0}), (0, 5, {'weight': 0}), (0, 134, {'weight': 0}), (0, 137, {'weight': 0}), (0, 11, {'weight': 0}), (0, 140, {'weight': 0}), (0, 143, {'weight': 0}), (0, 272, {'weight': 0}), (0, 17, {'weight': 0}), (0, 274, {'weight': 0}), (0, 21, {'weight': 0}), (0, 23, {'weight': 0}), (0, 25, {'weight': 0}), (0, 27, {'weight': 0}), (0, 157, {'weight': 0}), (0, 260, {'weight': 0}), (0, 32, {'weight': 0}), (0, 34, {'weight': 0}), (0, 163, {'weight': 0}), (0, 36, {'weight': 0}), (0, 38, {'weight': 0}), (0, 40, {'weight': 0}), (0, 169, {'weight': 0}), (0, 42, {'weight': 0}), (0, 171, {'weight': 0}), (0, 45, {'weight': 0}), (0, 174, {'weight': 0}), (0, 47, {'weight': 0}), (0, 49, {'weight': 0}), (0, 51, {'weight': 0}), (0, 53, {'weight': 0}), (0, 182, {'weight': 0}), (0, 55, {'weight': 0}), (0, 57, {'weight': 0}), (0, 59, {'weight': 0}), (0, 151, {'weight': 0}), (0, 61, {'weight': 0}), (0, 190, {'weight': 0}), (0, 63, {'weight': 0}), (0, 65, {'weight': 0}), (0, 67, {'weight': 0}), (0, 69, {'weight': 0}), (0, 71, {'weight': 0}), (0, 73, {'weight': 0}), (0, 75, {'weight': 0}), (0, 219, {'weight': 0}), (0, 207, {'weight': 0}), (0, 80, {'weight': 0}), (0, 209, {'weight': 0}), (0, 82, {'weight': 0}), (0, 84, {'weight': 0}), (0, 213, {'weight': 0}), (0, 86, {'weight': 0}), (0, 89, {'weight': 0}), (0, 91, {'weight': 0}), (0, 93, {'weight': 0}), (0, 95, {'weight': 0}), (0, 97, {'weight': 0}), (0, 99, {'weight': 0}), (0, 166, {'weight': 0}), (0, 102, {'weight': 0}), (0, 145, {'weight': 0}), (0, 104, {'weight': 0}), (0, 188, {'weight': 0}), (0, 106, {'weight': 0}), (0, 231, {'weight': 0}), (0, 109, {'weight': 0}), (0, 111, {'weight': 0}), (0, 217, {'weight': 0}), (0, 115, {'weight': 0}), (0, 245, {'weight': 0}), (0, 119, {'weight': 0}), (0, 153, {'weight': 0}), (0, 122, {'weight': 0}), (0, 277, {'weight': 0})], 1: [(1, 2, {'weight': 5, 'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['\x00'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['\x00'])})], 3: [(3, 4, {'weight': 5, 'rule': ParserRule(production=u'\u0943', prev_classes=None, prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.ri'])}), (3, 262, {'weight': 4, 'rule': ParserRule(production=u'\u090b', prev_classes=['vowel'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri'])}), (3, 247, {'weight': 4, 'rule': ParserRule(production=u'\u090b', prev_classes=['wb'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri'])})], 5: [(5, 266, {'weight': 5, 'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['a'])}), (5, 161, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a'])}), (5, 8, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a'])}), (5, 44, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a'])}), (5, 6, {'weight': 0}), (5, 19, {'weight': 0})], 6: [(6, 147, {'weight': 4, 'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '(('])}), (6, 7, {'weight': 4, 'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '(('])}), (6, 16, {'weight': 3, 'rule':  ...

# %%
import networkx as nx

# %%
nx.to_dict_of_dicts(nagarip.DG)
# Out:
# {0: {1: {'weight': 0},
#   3: {'weight': 0},
#   5: {'weight': 0},
#   11: {'weight': 0},
#   17: {'weight': 0},
#   21: {'weight': 0},
#   23: {'weight': 0},
#   25: {'weight': 0},
#   27: {'weight': 0},
#   32: {'weight': 0},
#   34: {'weight': 0},
#   36: {'weight': 0},
#   38: {'weight': 0},
#   40: {'weight': 0},
#   42: {'weight': 0},
#   45: {'weight': 0},
#   47: {'weight': 0},
#   49: {'weight': 0},
#   51: {'weight': 0},
#   53: {'weight': 0},
#   55: {'weight': 0},
#   57: {'weight': 0},
#   59: {'weight': 0},
#   61: {'weight': 0},
#   63: {'weight': 0},
#   65: {'weight': 0},
#   67: {'weight': 0},
#   69: {'weight': 0},
#   71: {'weight': 0},
#   73: {'weight': 0},
#   75: {'weight': 0},
#   80: {'weight': 0},
#   82: {'weight': 0},
#   84: {'weight': 0},
#   86: {'weight': 0},
#   89: {'weight': 0},
#   91: {'weight': 0},
#   93: {'weight': 0},
#   95: {'weight': 0},
#   97: {'weight': 0},
#   99: {'weight': 0},
#   102: {'weight': 0},
#   104: {'weight': 0},
#   106: {'weight': 0},
#   109: {'weight': 0},
#   111: {'weight': 0},
#   115: {'weight': 0},
#   119: {'weight': 0},
#   122: {'weight': 0},
#   130: {'weight': 0},
#   134: {'weight': 0},
#   137: {'weight': 0},
#   140: {'weight': 0},
#   143: {'weight': 0},
#   145: {'weight': 0},
#   151: {'weight': 0},
#   153: {'weight': 0},
#   157: {'weight': 0},
#   163: {'weight': 0},
#   166: {'weight': 0},
#   169: {'weight': 0},
#   171: {'weight': 0},
#   174: {'weight': 0},
#   182: {'weight': 0},
#   188: {'weight': 0},
#   190: {'weight': 0},
#   207: {'weight': 0},
#   209: {'weight': 0},
#   213: {'weight': 0},
#   217: {'weight': 0},
#   219: {'weight': 0},
#   223: {'weight': 0},
#   231: {'weight': 0},
#   245: {'weight': 0},
#   260: {'weight': 0},
#   272: {'weight': 0},
#   274: {'weight': 0},
#   277: {'weight': 0}},
#  1: {2: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['\x00'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['\x00']),
#    'weight': 5}},
#  2: {},
#  3: {4: {'rule': ParserRule(production=u'\u0943', prev_classes=None, prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.ri']),
#    'weight': 5},
#   247: {'rule': ParserRule(production=u'\u090b', prev_classes=['wb'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri']),
#    'weight': 4},
#   262: {'rule': ParserRule(production=u'\u090b', prev_classes=['vowel'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri']),
#    'weight': 4}},
#  4: {},
#  5: {6: {'weight': 0},
#   8: {'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4},
#   19: {'weight': 0},
#   44: {'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4},
#   161: {'rule': ParserRule(production=u'\u0905', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4},
#   266: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['a']),
#    'weight': 5}},
#  6: {7: {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '((']),
#    'weight': 4},
#   9: {'weight': 0},
#   16: {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=['vowel'], prev=1, next=3, match_tokens=['a', '((']),
#    'weight': 3},
#   147: {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '((']),
#    'weight': 4}},
#  7: {},
#  8: {},
#  9: {10: {'rule': ParserRule(production=u'\u0906', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=['a', '((', 'aa']),
#    'weight': 4}},
#  10: {},
#  11: {12: {'weight': 0},
#   283: {'rule': ParserRule(production=u'\u092f', prev_classes=None, prev_tokens=None, tokens=['y'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['y']),
#    'weight': 5}},
#  12: {13: {'weight': 0}},
#  13: {14: {'weight': 0},
#   240: {'rule': ParserRule(production=u'\u092f\u0947', prev_classes=['wb'], prev_tokens=None, tokens=['y', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['y', 'i', 'h']),
#    'weight': 3}},
#  14: {15: {'rule': ParserRule(production=u'\u092f\u0939\u0940', prev_classes=['wb'], prev_tokens=None, tokens=['y', 'i', 'h', 'ii'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['y', 'i', 'h', 'ii']),
#    'weight': 3}},
#  15: {},
#  16: {},
#  17: {18: {'rule': ParserRule(production=u'\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3},
#   173: {'rule': ParserRule(production=u'\u0902', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['consonant'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3},
#   184: {'weight': 0},
#   202: {'weight': 0},
#   216: {'rule': ParserRule(production=u'\u0928', prev_classes=None, prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['n']),
#    'weight': 5},
#   257: {'weight': 0},
#   271: {'rule': ParserRule(production=u'\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['vowel'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3}},
#  18: {},
#  19: {20: {'rule': ParserRule(production=u'\u0906', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   79: {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   101: {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant', 'short_vowel', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=4, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   142: {'rule': ParserRule(production=u'\u0906', prev_classes=['vowel'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   212: {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=2, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   215: {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['izaafat'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3},
#   243: {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['izaafat'], prev=2, next=3, match_tokens=['a', 'h']),
#    'weight': 3}},
#  20: {},
#  21: {22: {'rule': ParserRule(production=u'\u0918', prev_classes=None, prev_tokens=None, tokens=['gh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['gh']),
#    'weight': 5}},
#  22: {},
#  23: {24: {'rule': ParserRule(production=' ', prev_classes=None, prev_tokens=None, tokens=' ', next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[' ']),
#    'weight': 5},
#   162: {'rule': ParserRule(production='', prev_classes=['izaafat'], prev_tokens=None, tokens=' ', next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[' ']),
#    'weight': 4}},
#  24: {},
#  25: {26: {'rule': ParserRule(production=u'\u095d', prev_classes=None, prev_tokens=None, tokens=[';rh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';rh']),
#    'weight': 5}},
#  26: {},
#  27: {28: {'weight': 0},
#   121: {'rule': ParserRule(production=u'\u090a', prev_classes=['vowel'], prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['uu']),
#    'weight': 4},
#   211: {'rule': ParserRule(production=u'\u0942', prev_classes=None, prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['uu']),
#    'weight': 5},
#   222: {'rule': ParserRule(production=u'\u090a', prev_classes=['wb'], prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['uu']),
#    'weight': 4}},
#  28: {29: {'weight': 0}, 228: {'weight': 0}},
#  29: {30: {'weight': 0}},
#  30: {31: {'rule': ParserRule(production=u'\u0941\u090f\u0901', prev_classes=['consonant'], prev_tokens=None, tokens=['uu', '))', 'e', ';n'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['uu', '))', 'e', ';n']),
#    'weight': 3}},
#  31: {},
#  32: {33: {'rule': ParserRule(production=u'\u0909', prev_classes=['wb'], prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['u']),
#    'weight': 4},
#   187: {'rule': ParserRule(production=u'\u0909', prev_classes=['vowel'], prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['u']),
#    'weight': 4},
#   248: {'weight': 0},
#   279: {'rule': ParserRule(production=u'\u0941', prev_classes=None, prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['u']),
#    'weight': 5}},
#  33: {},
#  34: {35: {'rule': ParserRule(production=u'\u090f', prev_classes=['wb'], prev_tokens=None, tokens=[';e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';e']),
#    'weight': 4},
#   108: {'rule': ParserRule(production=u'\u0947', prev_classes=None, prev_tokens=None, tokens=[';e'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';e']),
#    'weight': 5}},
#  35: {},
#  36: {37: {'rule': ParserRule(production='(', prev_classes=None, prev_tokens=None, tokens=['('], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['(']),
#    'weight': 5}},
#  37: {},
#  38: {39: {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=['.s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.s']),
#    'weight': 5}},
#  39: {},
#  40: {41: {'rule': ParserRule(production=u'\u0913', prev_classes=['wb'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4},
#   236: {'rule': ParserRule(production=u'\u094b', prev_classes=['consonant'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4},
#   239: {'rule': ParserRule(production=u'\u0913', prev_classes=['vowel'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4},
#   264: {'weight': 0}},
#  41: {},
#  42: {43: {'rule': ParserRule(production=',', prev_classes=None, prev_tokens=None, tokens=[','], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[',']),
#    'weight': 5}},
#  43: {},
#  44: {},
#  45: {46: {'rule': ParserRule(production=u'\u090f', prev_classes=['wb'], prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['e']),
#    'weight': 4},
#   179: {'rule': ParserRule(production=u'\u090f', prev_classes=['vowel'], prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['e']),
#    'weight': 4},
#   268: {'rule': ParserRule(production=u'\u0947', prev_classes=None, prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['e']),
#    'weight': 5}},
#  46: {},
#  47: {48: {'rule': ParserRule(production=u'\u0925', prev_classes=None, prev_tokens=None, tokens=['th'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['th']),
#    'weight': 5}},
#  48: {},
#  49: {50: {'rule': ParserRule(production=u'\u0907', prev_classes=['wb'], prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['i']),
#    'weight': 4},
#   124: {'weight': 0},
#   180: {'rule': ParserRule(production=u'\u0907', prev_classes=['vowel'], prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['i']),
#    'weight': 4},
#   270: {'rule': ParserRule(production=u'\u093f', prev_classes=None, prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['i']),
#    'weight': 5}},
#  50: {},
#  51: {52: {'rule': ParserRule(production=u'\u0901', prev_classes=['candrabindu_vowel'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=[';n']),
#    'weight': 3},
#   88: {'rule': ParserRule(production=u'\u0901', prev_classes=['vowel', 'e'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=2, next=2, match_tokens=[';n']),
#    'weight': 3},
#   114: {'rule': ParserRule(production=u'\u0902', prev_classes=None, prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';n']),
#    'weight': 5},
#   276: {'rule': ParserRule(production=u'\u0902', prev_classes=['r', 'consonant', 'candrabindu_vowel'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=3, next=2, match_tokens=[';n']),
#    'weight': 3}},
#  52: {},
#  53: {54: {'rule': ParserRule(production=u'\u0913', prev_classes=['wb'], prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['o']),
#    'weight': 4},
#   168: {'rule': ParserRule(production=u'\u094b', prev_classes=None, prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['o']),
#    'weight': 5},
#   181: {'rule': ParserRule(production=u'\u0913', prev_classes=['vowel'], prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['o']),
#    'weight': 4}},
#  54: {},
#  55: {56: {'rule': ParserRule(production=u'\u0928', prev_classes=None, prev_tokens=None, tokens=[':n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':n']),
#    'weight': 5}},
#  56: {},
#  57: {58: {'rule': ParserRule(production='\n', prev_classes=None, prev_tokens=None, tokens=['\n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['\n']),
#    'weight': 5}},
#  58: {},
#  59: {60: {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4},
#   227: {'rule': ParserRule(production=u'\u093e', prev_classes=None, prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['aa']),
#    'weight': 5},
#   244: {'rule': ParserRule(production=u'\u0906', prev_classes=['short_vowel'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4},
#   280: {'rule': ParserRule(production=u'\u0906', prev_classes=['vowel'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4}},
#  60: {},
#  61: {62: {'rule': ParserRule(production=u'\u0927', prev_classes=None, prev_tokens=None, tokens=['dh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['dh']),
#    'weight': 5}},
#  62: {},
#  63: {64: {'rule': ParserRule(production=u'\u0910', prev_classes=['wb'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4},
#   139: {'rule': ParserRule(production=u'\u0910', prev_classes=['short_vowel'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4},
#   235: {'rule': ParserRule(production=u'\u0948', prev_classes=None, prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ai']),
#    'weight': 5},
#   288: {'rule': ParserRule(production=u'\u0910', prev_classes=['vowel'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4}},
#  64: {},
#  65: {66: {'rule': ParserRule(production=u'\u0914', prev_classes=['wb'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4},
#   200: {'rule': ParserRule(production=u'\u0914', prev_classes=['short_vowel'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4},
#   238: {'rule': ParserRule(production=u'\u094c', prev_classes=None, prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['au']),
#    'weight': 5},
#   267: {'rule': ParserRule(production=u'\u0914', prev_classes=['vowel'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4}},
#  66: {},
#  67: {68: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['((']),
#    'weight': 5},
#   113: {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=['<izaafat'], prev=1, next=2, match_tokens=['((']),
#    'weight': 3},
#   117: {'weight': 0},
#   128: {'weight': 0},
#   132: {'weight': 0},
#   196: {'weight': 0},
#   198: {'weight': 0},
#   204: {'weight': 0},
#   225: {'weight': 0},
#   284: {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=['((']),
#    'weight': 3}},
#  68: {},
#  69: {70: {'rule': ParserRule(production=u'\u0908', prev_classes=['wb'], prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ii']),
#    'weight': 4},
#   237: {'rule': ParserRule(production=u'\u0940', prev_classes=None, prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ii']),
#    'weight': 5},
#   269: {'rule': ParserRule(production=u'\u0908', prev_classes=['vowel'], prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ii']),
#    'weight': 4}},
#  70: {},
#  71: {72: {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=[':z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':z']),
#    'weight': 5}},
#  72: {},
#  73: {74: {'rule': ParserRule(production=u'\u0924', prev_classes=None, prev_tokens=None, tokens=[':t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':t']),
#    'weight': 5}},
#  74: {},
#  75: {76: {'weight': 0},
#   221: {'rule': ParserRule(production=u'\u0935', prev_classes=None, prev_tokens=None, tokens=['v'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['v']),
#    'weight': 5}},
#  76: {77: {'weight': 0}},
#  77: {78: {'rule': ParserRule(production=u'\u0935\u094b', prev_classes=['wb'], prev_tokens=None, tokens=['v', 'u', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['v', 'u', 'h']),
#    'weight': 3},
#   255: {'weight': 0}},
#  78: {},
#  79: {},
#  80: {81: {'rule': ParserRule(production=u'\u0926', prev_classes=None, prev_tokens=None, tokens=['d'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['d']),
#    'weight': 5}},
#  81: {},
#  82: {83: {'rule': ParserRule(production=u'\u0939', prev_classes=None, prev_tokens=None, tokens=['h'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['h']),
#    'weight': 5}},
#  83: {},
#  84: {85: {'rule': ParserRule(production=u'\u0932', prev_classes=None, prev_tokens=None, tokens=['l'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['l']),
#    'weight': 5}},
#  85: {},
#  86: {87: {'rule': ParserRule(production=u'\u092a', prev_classes=None, prev_tokens=None, tokens=['p'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['p']),
#    'weight': 5},
#   148: {'weight': 0}},
#  87: {},
#  88: {},
#  89: {90: {'rule': ParserRule(production=u'\u0924', prev_classes=None, prev_tokens=None, tokens=['t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['t']),
#    'weight': 5}},
#  90: {},
#  91: {92: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['|'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['|']),
#    'weight': 5}},
#  92: {},
#  93: {94: {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=[';s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';s']),
#    'weight': 5}},
#  94: {},
#  95: {96: {'rule': ParserRule(production=u'\u095c', prev_classes=None, prev_tokens=None, tokens=[';r'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';r']),
#    'weight': 5}},
#  96: {},
#  97: {98: {'rule': ParserRule(production=u'\u091d\u093c', prev_classes=None, prev_tokens=None, tokens=['zh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['zh']),
#    'weight': 5}},
#  98: {},
#  99: {100: {'rule': ParserRule(production=u'\u091f', prev_classes=None, prev_tokens=None, tokens=[';t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';t']),
#    'weight': 5}},
#  100: {},
#  101: {},
#  102: {103: {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=[';z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';z']),
#    'weight': 5}},
#  103: {},
#  104: {105: {'rule': ParserRule(production=u'\u0959', prev_classes=None, prev_tokens=None, tokens=[';x'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';x']),
#    'weight': 5},
#   176: {'weight': 0}},
#  105: {},
#  106: {107: {'rule': ParserRule(production=u'\u0922', prev_classes=None, prev_tokens=None, tokens=[';dh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';dh']),
#    'weight': 5}},
#  107: {},
#  108: {},
#  109: {110: {'rule': ParserRule(production=u'\u0921', prev_classes=None, prev_tokens=None, tokens=[';d'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';d']),
#    'weight': 5}},
#  110: {},
#  111: {112: {'rule': ParserRule(production=u'\u0939', prev_classes=None, prev_tokens=None, tokens=[';h'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';h']),
#    'weight': 5}},
#  112: {},
#  113: {},
#  114: {},
#  115: {116: {'rule': ParserRule(production=u'\u0901', prev_classes=None, prev_tokens=None, tokens=[';m'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';m']),
#    'weight': 5}},
#  116: {},
#  117: {118: {'rule': ParserRule(production=u'\u0909', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'u'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'u']),
#    'weight': 4}},
#  118: {},
#  119: {120: {'rule': ParserRule(production=u'\u0920', prev_classes=None, prev_tokens=None, tokens=[';th'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';th']),
#    'weight': 5}},
#  120: {},
#  121: {},
#  122: {123: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=["'"], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=["'"]),
#    'weight': 5}},
#  123: {},
#  124: {125: {'weight': 0}},
#  125: {126: {'weight': 0}},
#  126: {127: {'rule': ParserRule(production=u'\u090f\u0924', prev_classes=['wb'], prev_tokens=None, tokens=['i', '((', 't', 'i'], next_tokens=None, next_classes=None, prev=1, next=4, match_tokens=['i', '((', 't', 'i']),
#    'weight': 4}},
#  127: {},
#  128: {129: {'rule': ParserRule(production=u'\u0907', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'i'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'i']),
#    'weight': 4},
#   136: {'rule': ParserRule(production=u'\u0907', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'i'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'i']),
#    'weight': 4}},
#  129: {},
#  130: {131: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['/'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['/']),
#    'weight': 5}},
#  131: {},
#  132: {133: {'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4},
#   201: {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['((', 'a']),
#    'weight': 3},
#   206: {'rule': ParserRule(production=u'\u0905', prev_classes=['consonant'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4},
#   263: {'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4}},
#  133: {},
#  134: {135: {'rule': ParserRule(production=u';', prev_classes=None, prev_tokens=None, tokens=[';'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';']),
#    'weight': 5}},
#  135: {},
#  136: {},
#  137: {138: {'rule': ParserRule(production='?', prev_classes=None, prev_tokens=None, tokens=['?'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['?']),
#    'weight': 5}},
#  138: {},
#  139: {},
#  140: {141: {'rule': ParserRule(production=u'\u2010\u090f\u2010', prev_classes=None, prev_tokens=None, tokens=['-e'], next_tokens=None, next_classes=['wb'], prev=0, next=2, match_tokens=['-e']),
#    'weight': 4}},
#  141: {},
#  142: {},
#  143: {144: {'rule': ParserRule(production=u'\u092d', prev_classes=None, prev_tokens=None, tokens=['bh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['bh']),
#    'weight': 5}},
#  144: {},
#  145: {146: {'rule': ParserRule(production=u'\u091d', prev_classes=None, prev_tokens=None, tokens=['jh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['jh']),
#    'weight': 5}},
#  146: {},
#  147: {},
#  148: {149: {'weight': 0}},
#  149: {150: {'rule': ParserRule(production=u'\u092a\u0947', prev_classes=['wb'], prev_tokens=None, tokens=['p', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['p', 'a', 'h']),
#    'weight': 3}},
#  150: {},
#  151: {152: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['_'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['_']),
#    'weight': 5}},
#  152: {},
#  153: {154: {'weight': 0},
#   192: {'weight': 0},
#   251: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['-'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['-']),
#    'weight': 5}},
#  154: {155: {'weight': 0}},
#  155: {156: {'rule': ParserRule(production=u'\u2010\u0913\u2010', prev_classes=None, prev_tokens=None, tokens=['-', 'o', '-'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['-', 'o', '-']),
#    'weight': 5}},
#  156: {},
#  157: {158: {'weight': 0},
#   165: {'rule': ParserRule(production=u'\u0915', prev_classes=None, prev_tokens=None, tokens=['k'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['k']),
#    'weight': 5}},
#  158: {159: {'weight': 0}},
#  159: {160: {'rule': ParserRule(production=u'\u0915\u093f', prev_classes=None, prev_tokens=None, tokens=['k', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=0, next=4, match_tokens=['k', 'i', 'h']),
#    'weight': 4}},
#  160: {},
#  161: {},
#  162: {},
#  163: {164: {'rule': ParserRule(production=u'\u0917', prev_classes=None, prev_tokens=None, tokens=['g'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['g']),
#    'weight': 5}},
#  164: {},
#  165: {},
#  166: {167: {'rule': ParserRule(production=u'\u093e', prev_classes=None, prev_tokens=None, tokens=[';aa'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';aa']),
#    'weight': 5}},
#  167: {},
#  168: {},
#  169: {170: {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=['s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['s']),
#    'weight': 5}},
#  170: {},
#  171: {172: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['w'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['w']),
#    'weight': 5}},
#  172: {},
#  173: {},
#  174: {175: {'rule': ParserRule(production=u'\u091a', prev_classes=None, prev_tokens=None, tokens=['ch'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ch']),
#    'weight': 5},
#   252: {'weight': 0}},
#  175: {},
#  176: {177: {'weight': 0}},
#  177: {178: {'rule': ParserRule(production=u'\u0959\u0941', prev_classes=['wb'], prev_tokens=None, tokens=[';x', 'v', 'u'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=[';x', 'v', 'u']),
#    'weight': 4}},
#  178: {},
#  179: {},
#  180: {},
#  181: {},
#  182: {183: {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['))'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['))']),
#    'weight': 5}},
#  183: {},
#  184: {185: {'weight': 0}, 241: {'weight': 0}, 281: {'weight': 0}},
#  185: {186: {'rule': ParserRule(production=u'\u0928\u0924\u0940', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'ii'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'ii']),
#    'weight': 5}},
#  186: {},
#  187: {},
#  188: {189: {'rule': ParserRule(production=u'\u091b', prev_classes=None, prev_tokens=None, tokens=['chh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['chh']),
#    'weight': 5}},
#  189: {},
#  190: {191: {'rule': ParserRule(production=u'\u092b', prev_classes=None, prev_tokens=None, tokens=['ph'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ph']),
#    'weight': 5}},
#  191: {},
#  192: {193: {'weight': 0}},
#  193: {194: {'weight': 0},
#   234: {'rule': ParserRule(production=u'\u2010\u0939\u093e', prev_classes=None, prev_tokens=None, tokens=['-', 'h', 'aa'], next_tokens=None, next_classes=['wb'], prev=0, next=4, match_tokens=['-', 'h', 'aa']),
#    'weight': 4}},
#  194: {195: {'rule': ParserRule(production=u'\u2010\u0939\u093e-\u090f-', prev_classes=None, prev_tokens=None, tokens=['-', 'h', 'aa', '-e'], next_tokens=None, next_classes=['wb'], prev=0, next=5, match_tokens=['-', 'h', 'aa', '-e']),
#    'weight': 4}},
#  195: {},
#  196: {197: {'rule': ParserRule(production=u'\u0914', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'au'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'au']),
#    'weight': 4}},
#  197: {},
#  198: {199: {'rule': ParserRule(production=u'\u0910', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'ai'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ai']),
#    'weight': 4}},
#  199: {},
#  200: {},
#  201: {},
#  202: {203: {'rule': ParserRule(production=u'\u0928\u094d\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n', 'n'], next_tokens=None, next_classes=['vowel'], prev=1, next=3, match_tokens=['n', 'n']),
#    'weight': 3}},
#  203: {},
#  204: {205: {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'aa']),
#    'weight': 4}},
#  205: {},
#  206: {},
#  207: {208: {'rule': ParserRule(production=u'\u092c', prev_classes=None, prev_tokens=None, tokens=['b'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['b']),
#    'weight': 5},
#   285: {'weight': 0}},
#  208: {},
#  209: {210: {'rule': ParserRule(production=u'\u095e', prev_classes=None, prev_tokens=None, tokens=['f'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['f']),
#    'weight': 5}},
#  210: {},
#  211: {},
#  212: {},
#  213: {214: {'rule': ParserRule(production=u'\u091c', prev_classes=None, prev_tokens=None, tokens=['j'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['j']),
#    'weight': 5}},
#  214: {},
#  215: {},
#  216: {},
#  217: {218: {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=['.z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.z']),
#    'weight': 5}},
#  218: {},
#  219: {220: {'rule': ParserRule(production=u'\u0930', prev_classes=None, prev_tokens=None, tokens=['r'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['r']),
#    'weight': 5}},
#  220: {},
#  221: {},
#  222: {},
#  223: {224: {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=['z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['z']),
#    'weight': 5}},
#  224: {},
#  225: {226: {'rule': ParserRule(production=u'\u0908', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'ii'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ii']),
#    'weight': 4},
#   233: {'rule': ParserRule(production=u'\u0908', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'ii'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ii']),
#    'weight': 4}},
#  226: {},
#  227: {},
#  228: {229: {'weight': 0}},
#  229: {230: {'rule': ParserRule(production=u'\u0941\u0913\u0902', prev_classes=['consonant'], prev_tokens=None, tokens=['uu', '))', 'o', ';n'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['uu', '))', 'o', ';n']),
#    'weight': 3}},
#  230: {},
#  231: {232: {'rule': ParserRule(production=u'\u0916', prev_classes=None, prev_tokens=None, tokens=['kh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['kh']),
#    'weight': 5}},
#  232: {},
#  233: {},
#  234: {},
#  235: {},
#  236: {},
#  237: {},
#  238: {},
#  239: {},
#  240: {},
#  241: {242: {'rule': ParserRule(production=u'\u0928\u0924\u0947', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'e'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'e']),
#    'weight': 5}},
#  242: {},
#  243: {},
#  244: {},
#  245: {246: {'rule': ParserRule(production=')', prev_classes=None, prev_tokens=None, tokens=[')'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[')']),
#    'weight': 5}},
#  246: {},
#  247: {},
#  248: {249: {'weight': 0}},
#  249: {250: {'rule': ParserRule(production=u'\u0941\u0906', prev_classes=['consonant'], prev_tokens=None, tokens=['u', '((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=['u', '((', 'aa']),
#    'weight': 4}},
#  250: {},
#  251: {},
#  252: {253: {'weight': 0}},
#  253: {254: {'rule': ParserRule(production=u'\u091a\u0947', prev_classes=['consonant'], prev_tokens=None, tokens=['ch', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['ch', 'i', 'h']),
#    'weight': 3}},
#  254: {},
#  255: {256: {'rule': ParserRule(production=u'\u0935\u0939\u0940', prev_classes=['wb'], prev_tokens=None, tokens=['v', 'u', 'h', 'ii'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['v', 'u', 'h', 'ii']),
#    'weight': 3}},
#  256: {},
#  257: {258: {'weight': 0}},
#  258: {259: {'rule': ParserRule(production=u'\u0928', prev_classes=['wb'], prev_tokens=None, tokens=['n', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['n', 'a', 'h']),
#    'weight': 3}},
#  259: {},
#  260: {261: {'rule': ParserRule(production=u'\u095a', prev_classes=None, prev_tokens=None, tokens=[';g'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';g']),
#    'weight': 5}},
#  261: {},
#  262: {},
#  263: {},
#  264: {265: {'rule': ParserRule(production=u'\u094b', prev_classes=['consonant'], prev_tokens=None, tokens=[';o', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=[';o', '((']),
#    'weight': 4}},
#  265: {},
#  266: {},
#  267: {},
#  268: {},
#  269: {},
#  270: {},
#  271: {},
#  272: {273: {'rule': ParserRule(production=u'\u092e', prev_classes=None, prev_tokens=None, tokens=['m'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['m']),
#    'weight': 5}},
#  273: {},
#  274: {275: {'rule': ParserRule(production=u'\u0958', prev_classes=None, prev_tokens=None, tokens=['q'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['q']),
#    'weight': 5}},
#  275: {},
#  276: {},
#  277: {278: {'rule': ParserRule(production=u'\u0936', prev_classes=None, prev_tokens=None, tokens=['sh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['sh']),
#    'weight': 5}},
#  278: {},
#  279: {},
#  280: {},
#  281: {282: {'rule': ParserRule(production=u'\u0928\u0924\u093e', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'aa'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'aa']),
#    'weight': 5}},
#  282: {},
#  283: {},
#  284: {},
#  285: {286: {'weight': 0}},
#  286: {287: {'rule': ParserRule(production=u'\u092c', prev_classes=['wb'], prev_tokens=None, tokens=['b', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['b', 'a', 'h']),
#    'weight': 3}},
#  287: {},
#  288: {}}

# %%
DG = nagarip.DG

# %%
nodes = DG.nodes(data=True)

# %%
edges = DG.edges(data=True)

# %%
nodes[0]
# Out:
# (0, {'token': None})

# %%
DG.edges(data=True)
# Out:
# [(0, 1, {'weight': 0}),
#  (0, 130, {'weight': 0}),
#  (0, 3, {'weight': 0}),
#  (0, 223, {'weight': 0}),
#  (0, 5, {'weight': 0}),
#  (0, 134, {'weight': 0}),
#  (0, 137, {'weight': 0}),
#  (0, 11, {'weight': 0}),
#  (0, 140, {'weight': 0}),
#  (0, 143, {'weight': 0}),
#  (0, 272, {'weight': 0}),
#  (0, 17, {'weight': 0}),
#  (0, 274, {'weight': 0}),
#  (0, 21, {'weight': 0}),
#  (0, 23, {'weight': 0}),
#  (0, 25, {'weight': 0}),
#  (0, 27, {'weight': 0}),
#  (0, 157, {'weight': 0}),
#  (0, 260, {'weight': 0}),
#  (0, 32, {'weight': 0}),
#  (0, 34, {'weight': 0}),
#  (0, 163, {'weight': 0}),
#  (0, 36, {'weight': 0}),
#  (0, 38, {'weight': 0}),
#  (0, 40, {'weight': 0}),
#  (0, 169, {'weight': 0}),
#  (0, 42, {'weight': 0}),
#  (0, 171, {'weight': 0}),
#  (0, 45, {'weight': 0}),
#  (0, 174, {'weight': 0}),
#  (0, 47, {'weight': 0}),
#  (0, 49, {'weight': 0}),
#  (0, 51, {'weight': 0}),
#  (0, 53, {'weight': 0}),
#  (0, 182, {'weight': 0}),
#  (0, 55, {'weight': 0}),
#  (0, 57, {'weight': 0}),
#  (0, 59, {'weight': 0}),
#  (0, 151, {'weight': 0}),
#  (0, 61, {'weight': 0}),
#  (0, 190, {'weight': 0}),
#  (0, 63, {'weight': 0}),
#  (0, 65, {'weight': 0}),
#  (0, 67, {'weight': 0}),
#  (0, 69, {'weight': 0}),
#  (0, 71, {'weight': 0}),
#  (0, 73, {'weight': 0}),
#  (0, 75, {'weight': 0}),
#  (0, 219, {'weight': 0}),
#  (0, 207, {'weight': 0}),
#  (0, 80, {'weight': 0}),
#  (0, 209, {'weight': 0}),
#  (0, 82, {'weight': 0}),
#  (0, 84, {'weight': 0}),
#  (0, 213, {'weight': 0}),
#  (0, 86, {'weight': 0}),
#  (0, 89, {'weight': 0}),
#  (0, 91, {'weight': 0}),
#  (0, 93, {'weight': 0}),
#  (0, 95, {'weight': 0}),
#  (0, 97, {'weight': 0}),
#  (0, 99, {'weight': 0}),
#  (0, 166, {'weight': 0}),
#  (0, 102, {'weight': 0}),
#  (0, 145, {'weight': 0}),
#  (0, 104, {'weight': 0}),
#  (0, 188, {'weight': 0}),
#  (0, 106, {'weight': 0}),
#  (0, 231, {'weight': 0}),
#  (0, 109, {'weight': 0}),
#  (0, 111, {'weight': 0}),
#  (0, 217, {'weight': 0}),
#  (0, 115, {'weight': 0}),
#  (0, 245, {'weight': 0}),
#  (0, 119, {'weight': 0}),
#  (0, 153, {'weight': 0}),
#  (0, 122, {'weight': 0}),
#  (0, 277, {'weight': 0}),
#  (1,
#   2,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['\x00'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['\x00']),
#    'weight': 5}),
#  (3,
#   4,
#   {'rule': ParserRule(production=u'\u0943', prev_classes=None, prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.ri']),
#    'weight': 5}),
#  (3,
#   262,
#   {'rule': ParserRule(production=u'\u090b', prev_classes=['vowel'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri']),
#    'weight': 4}),
#  (3,
#   247,
#   {'rule': ParserRule(production=u'\u090b', prev_classes=['wb'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['.ri']),
#    'weight': 4}),
#  (5,
#   161,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4}),
#  (5, 6, {'weight': 0}),
#  (5,
#   8,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4}),
#  (5,
#   266,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['a']),
#    'weight': 5}),
#  (5,
#   44,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['a']),
#    'weight': 4}),
#  (5, 19, {'weight': 0}),
#  (6,
#   16,
#   {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=['vowel'], prev=1, next=3, match_tokens=['a', '((']),
#    'weight': 3}),
#  (6, 9, {'weight': 0}),
#  (6,
#   147,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '((']),
#    'weight': 4}),
#  (6,
#   7,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['a', '((']),
#    'weight': 4}),
#  (9,
#   10,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=['a', '((', 'aa']),
#    'weight': 4}),
#  (11,
#   283,
#   {'rule': ParserRule(production=u'\u092f', prev_classes=None, prev_tokens=None, tokens=['y'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['y']),
#    'weight': 5}),
#  (11, 12, {'weight': 0}),
#  (12, 13, {'weight': 0}),
#  (13,
#   240,
#   {'rule': ParserRule(production=u'\u092f\u0947', prev_classes=['wb'], prev_tokens=None, tokens=['y', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['y', 'i', 'h']),
#    'weight': 3}),
#  (13, 14, {'weight': 0}),
#  (14,
#   15,
#   {'rule': ParserRule(production=u'\u092f\u0939\u0940', prev_classes=['wb'], prev_tokens=None, tokens=['y', 'i', 'h', 'ii'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['y', 'i', 'h', 'ii']),
#    'weight': 3}),
#  (17, 257, {'weight': 0}),
#  (17, 202, {'weight': 0}),
#  (17,
#   173,
#   {'rule': ParserRule(production=u'\u0902', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['consonant'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3}),
#  (17,
#   271,
#   {'rule': ParserRule(production=u'\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['vowel'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3}),
#  (17,
#   216,
#   {'rule': ParserRule(production=u'\u0928', prev_classes=None, prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['n']),
#    'weight': 5}),
#  (17,
#   18,
#   {'rule': ParserRule(production=u'\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n'], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=['n']),
#    'weight': 3}),
#  (17, 184, {'weight': 0}),
#  (19,
#   101,
#   {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant', 'short_vowel', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=4, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   142,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['vowel'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   79,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   243,
#   {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['izaafat'], prev=2, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   212,
#   {'rule': ParserRule(production=u'\u0939', prev_classes=['wb', 'consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=2, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   215,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['izaafat'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (19,
#   20,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['a', 'h']),
#    'weight': 3}),
#  (21,
#   22,
#   {'rule': ParserRule(production=u'\u0918', prev_classes=None, prev_tokens=None, tokens=['gh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['gh']),
#    'weight': 5}),
#  (23,
#   24,
#   {'rule': ParserRule(production=' ', prev_classes=None, prev_tokens=None, tokens=' ', next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[' ']),
#    'weight': 5}),
#  (23,
#   162,
#   {'rule': ParserRule(production='', prev_classes=['izaafat'], prev_tokens=None, tokens=' ', next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[' ']),
#    'weight': 4}),
#  (25,
#   26,
#   {'rule': ParserRule(production=u'\u095d', prev_classes=None, prev_tokens=None, tokens=[';rh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';rh']),
#    'weight': 5}),
#  (27,
#   121,
#   {'rule': ParserRule(production=u'\u090a', prev_classes=['vowel'], prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['uu']),
#    'weight': 4}),
#  (27,
#   211,
#   {'rule': ParserRule(production=u'\u0942', prev_classes=None, prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['uu']),
#    'weight': 5}),
#  (27, 28, {'weight': 0}),
#  (27,
#   222,
#   {'rule': ParserRule(production=u'\u090a', prev_classes=['wb'], prev_tokens=None, tokens=['uu'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['uu']),
#    'weight': 4}),
#  (28, 228, {'weight': 0}),
#  (28, 29, {'weight': 0}),
#  (29, 30, {'weight': 0}),
#  (30,
#   31,
#   {'rule': ParserRule(production=u'\u0941\u090f\u0901', prev_classes=['consonant'], prev_tokens=None, tokens=['uu', '))', 'e', ';n'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['uu', '))', 'e', ';n']),
#    'weight': 3}),
#  (32, 248, {'weight': 0}),
#  (32,
#   33,
#   {'rule': ParserRule(production=u'\u0909', prev_classes=['wb'], prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['u']),
#    'weight': 4}),
#  (32,
#   187,
#   {'rule': ParserRule(production=u'\u0909', prev_classes=['vowel'], prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['u']),
#    'weight': 4}),
#  (32,
#   279,
#   {'rule': ParserRule(production=u'\u0941', prev_classes=None, prev_tokens=None, tokens=['u'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['u']),
#    'weight': 5}),
#  (34,
#   35,
#   {'rule': ParserRule(production=u'\u090f', prev_classes=['wb'], prev_tokens=None, tokens=[';e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';e']),
#    'weight': 4}),
#  (34,
#   108,
#   {'rule': ParserRule(production=u'\u0947', prev_classes=None, prev_tokens=None, tokens=[';e'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';e']),
#    'weight': 5}),
#  (36,
#   37,
#   {'rule': ParserRule(production='(', prev_classes=None, prev_tokens=None, tokens=['('], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['(']),
#    'weight': 5}),
#  (38,
#   39,
#   {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=['.s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.s']),
#    'weight': 5}),
#  (40, 264, {'weight': 0}),
#  (40,
#   41,
#   {'rule': ParserRule(production=u'\u0913', prev_classes=['wb'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4}),
#  (40,
#   236,
#   {'rule': ParserRule(production=u'\u094b', prev_classes=['consonant'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4}),
#  (40,
#   239,
#   {'rule': ParserRule(production=u'\u0913', prev_classes=['vowel'], prev_tokens=None, tokens=[';o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=[';o']),
#    'weight': 4}),
#  (42,
#   43,
#   {'rule': ParserRule(production=',', prev_classes=None, prev_tokens=None, tokens=[','], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[',']),
#    'weight': 5}),
#  (45,
#   179,
#   {'rule': ParserRule(production=u'\u090f', prev_classes=['vowel'], prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['e']),
#    'weight': 4}),
#  (45,
#   268,
#   {'rule': ParserRule(production=u'\u0947', prev_classes=None, prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['e']),
#    'weight': 5}),
#  (45,
#   46,
#   {'rule': ParserRule(production=u'\u090f', prev_classes=['wb'], prev_tokens=None, tokens=['e'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['e']),
#    'weight': 4}),
#  (47,
#   48,
#   {'rule': ParserRule(production=u'\u0925', prev_classes=None, prev_tokens=None, tokens=['th'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['th']),
#    'weight': 5}),
#  (49,
#   180,
#   {'rule': ParserRule(production=u'\u0907', prev_classes=['vowel'], prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['i']),
#    'weight': 4}),
#  (49,
#   50,
#   {'rule': ParserRule(production=u'\u0907', prev_classes=['wb'], prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['i']),
#    'weight': 4}),
#  (49, 124, {'weight': 0}),
#  (49,
#   270,
#   {'rule': ParserRule(production=u'\u093f', prev_classes=None, prev_tokens=None, tokens=['i'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['i']),
#    'weight': 5}),
#  (51,
#   88,
#   {'rule': ParserRule(production=u'\u0901', prev_classes=['vowel', 'e'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=2, next=2, match_tokens=[';n']),
#    'weight': 3}),
#  (51,
#   276,
#   {'rule': ParserRule(production=u'\u0902', prev_classes=['r', 'consonant', 'candrabindu_vowel'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=3, next=2, match_tokens=[';n']),
#    'weight': 3}),
#  (51,
#   114,
#   {'rule': ParserRule(production=u'\u0902', prev_classes=None, prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';n']),
#    'weight': 5}),
#  (51,
#   52,
#   {'rule': ParserRule(production=u'\u0901', prev_classes=['candrabindu_vowel'], prev_tokens=None, tokens=[';n'], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=[';n']),
#    'weight': 3}),
#  (53,
#   168,
#   {'rule': ParserRule(production=u'\u094b', prev_classes=None, prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['o']),
#    'weight': 5}),
#  (53,
#   181,
#   {'rule': ParserRule(production=u'\u0913', prev_classes=['vowel'], prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['o']),
#    'weight': 4}),
#  (53,
#   54,
#   {'rule': ParserRule(production=u'\u0913', prev_classes=['wb'], prev_tokens=None, tokens=['o'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['o']),
#    'weight': 4}),
#  (55,
#   56,
#   {'rule': ParserRule(production=u'\u0928', prev_classes=None, prev_tokens=None, tokens=[':n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':n']),
#    'weight': 5}),
#  (57,
#   58,
#   {'rule': ParserRule(production='\n', prev_classes=None, prev_tokens=None, tokens=['\n'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['\n']),
#    'weight': 5}),
#  (59,
#   280,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['vowel'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4}),
#  (59,
#   244,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['short_vowel'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4}),
#  (59,
#   227,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=None, prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['aa']),
#    'weight': 5}),
#  (59,
#   60,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['aa'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['aa']),
#    'weight': 4}),
#  (61,
#   62,
#   {'rule': ParserRule(production=u'\u0927', prev_classes=None, prev_tokens=None, tokens=['dh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['dh']),
#    'weight': 5}),
#  (63,
#   64,
#   {'rule': ParserRule(production=u'\u0910', prev_classes=['wb'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4}),
#  (63,
#   288,
#   {'rule': ParserRule(production=u'\u0910', prev_classes=['vowel'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4}),
#  (63,
#   139,
#   {'rule': ParserRule(production=u'\u0910', prev_classes=['short_vowel'], prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ai']),
#    'weight': 4}),
#  (63,
#   235,
#   {'rule': ParserRule(production=u'\u0948', prev_classes=None, prev_tokens=None, tokens=['ai'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ai']),
#    'weight': 5}),
#  (65,
#   200,
#   {'rule': ParserRule(production=u'\u0914', prev_classes=['short_vowel'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4}),
#  (65,
#   66,
#   {'rule': ParserRule(production=u'\u0914', prev_classes=['wb'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4}),
#  (65,
#   267,
#   {'rule': ParserRule(production=u'\u0914', prev_classes=['vowel'], prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['au']),
#    'weight': 4}),
#  (65,
#   238,
#   {'rule': ParserRule(production=u'\u094c', prev_classes=None, prev_tokens=None, tokens=['au'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['au']),
#    'weight': 5}),
#  (67, 128, {'weight': 0}),
#  (67,
#   68,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['((']),
#    'weight': 5}),
#  (67, 132, {'weight': 0}),
#  (67, 198, {'weight': 0}),
#  (67, 225, {'weight': 0}),
#  (67, 204, {'weight': 0}),
#  (67,
#   113,
#   {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=['<izaafat'], prev=1, next=2, match_tokens=['((']),
#    'weight': 3}),
#  (67, 117, {'weight': 0}),
#  (67, 196, {'weight': 0}),
#  (67,
#   284,
#   {'rule': ParserRule(production='', prev_classes=['consonant'], prev_tokens=None, tokens=['(('], next_tokens=None, next_classes=['wb'], prev=1, next=2, match_tokens=['((']),
#    'weight': 3}),
#  (69,
#   237,
#   {'rule': ParserRule(production=u'\u0940', prev_classes=None, prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ii']),
#    'weight': 5}),
#  (69,
#   70,
#   {'rule': ParserRule(production=u'\u0908', prev_classes=['wb'], prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ii']),
#    'weight': 4}),
#  (69,
#   269,
#   {'rule': ParserRule(production=u'\u0908', prev_classes=['vowel'], prev_tokens=None, tokens=['ii'], next_tokens=None, next_classes=None, prev=1, next=1, match_tokens=['ii']),
#    'weight': 4}),
#  (71,
#   72,
#   {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=[':z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':z']),
#    'weight': 5}),
#  (73,
#   74,
#   {'rule': ParserRule(production=u'\u0924', prev_classes=None, prev_tokens=None, tokens=[':t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[':t']),
#    'weight': 5}),
#  (75, 76, {'weight': 0}),
#  (75,
#   221,
#   {'rule': ParserRule(production=u'\u0935', prev_classes=None, prev_tokens=None, tokens=['v'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['v']),
#    'weight': 5}),
#  (76, 77, {'weight': 0}),
#  (77,
#   78,
#   {'rule': ParserRule(production=u'\u0935\u094b', prev_classes=['wb'], prev_tokens=None, tokens=['v', 'u', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['v', 'u', 'h']),
#    'weight': 3}),
#  (77, 255, {'weight': 0}),
#  (80,
#   81,
#   {'rule': ParserRule(production=u'\u0926', prev_classes=None, prev_tokens=None, tokens=['d'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['d']),
#    'weight': 5}),
#  (82,
#   83,
#   {'rule': ParserRule(production=u'\u0939', prev_classes=None, prev_tokens=None, tokens=['h'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['h']),
#    'weight': 5}),
#  (84,
#   85,
#   {'rule': ParserRule(production=u'\u0932', prev_classes=None, prev_tokens=None, tokens=['l'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['l']),
#    'weight': 5}),
#  (86, 148, {'weight': 0}),
#  (86,
#   87,
#   {'rule': ParserRule(production=u'\u092a', prev_classes=None, prev_tokens=None, tokens=['p'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['p']),
#    'weight': 5}),
#  (89,
#   90,
#   {'rule': ParserRule(production=u'\u0924', prev_classes=None, prev_tokens=None, tokens=['t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['t']),
#    'weight': 5}),
#  (91,
#   92,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['|'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['|']),
#    'weight': 5}),
#  (93,
#   94,
#   {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=[';s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';s']),
#    'weight': 5}),
#  (95,
#   96,
#   {'rule': ParserRule(production=u'\u095c', prev_classes=None, prev_tokens=None, tokens=[';r'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';r']),
#    'weight': 5}),
#  (97,
#   98,
#   {'rule': ParserRule(production=u'\u091d\u093c', prev_classes=None, prev_tokens=None, tokens=['zh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['zh']),
#    'weight': 5}),
#  (99,
#   100,
#   {'rule': ParserRule(production=u'\u091f', prev_classes=None, prev_tokens=None, tokens=[';t'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';t']),
#    'weight': 5}),
#  (102,
#   103,
#   {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=[';z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';z']),
#    'weight': 5}),
#  (104, 176, {'weight': 0}),
#  (104,
#   105,
#   {'rule': ParserRule(production=u'\u0959', prev_classes=None, prev_tokens=None, tokens=[';x'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';x']),
#    'weight': 5}),
#  (106,
#   107,
#   {'rule': ParserRule(production=u'\u0922', prev_classes=None, prev_tokens=None, tokens=[';dh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';dh']),
#    'weight': 5}),
#  (109,
#   110,
#   {'rule': ParserRule(production=u'\u0921', prev_classes=None, prev_tokens=None, tokens=[';d'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';d']),
#    'weight': 5}),
#  (111,
#   112,
#   {'rule': ParserRule(production=u'\u0939', prev_classes=None, prev_tokens=None, tokens=[';h'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';h']),
#    'weight': 5}),
#  (115,
#   116,
#   {'rule': ParserRule(production=u'\u0901', prev_classes=None, prev_tokens=None, tokens=[';m'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';m']),
#    'weight': 5}),
#  (117,
#   118,
#   {'rule': ParserRule(production=u'\u0909', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'u'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'u']),
#    'weight': 4}),
#  (119,
#   120,
#   {'rule': ParserRule(production=u'\u0920', prev_classes=None, prev_tokens=None, tokens=[';th'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';th']),
#    'weight': 5}),
#  (122,
#   123,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=["'"], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=["'"]),
#    'weight': 5}),
#  (124, 125, {'weight': 0}),
#  (125, 126, {'weight': 0}),
#  (126,
#   127,
#   {'rule': ParserRule(production=u'\u090f\u0924', prev_classes=['wb'], prev_tokens=None, tokens=['i', '((', 't', 'i'], next_tokens=None, next_classes=None, prev=1, next=4, match_tokens=['i', '((', 't', 'i']),
#    'weight': 4}),
#  (128,
#   136,
#   {'rule': ParserRule(production=u'\u0907', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'i'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'i']),
#    'weight': 4}),
#  (128,
#   129,
#   {'rule': ParserRule(production=u'\u0907', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'i'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'i']),
#    'weight': 4}),
#  (130,
#   131,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['/'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['/']),
#    'weight': 5}),
#  (132,
#   201,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=['wb'], prev=1, next=3, match_tokens=['((', 'a']),
#    'weight': 3}),
#  (132,
#   133,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4}),
#  (132,
#   206,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['consonant'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4}),
#  (132,
#   263,
#   {'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'a'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'a']),
#    'weight': 4}),
#  (134,
#   135,
#   {'rule': ParserRule(production=u';', prev_classes=None, prev_tokens=None, tokens=[';'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';']),
#    'weight': 5}),
#  (137,
#   138,
#   {'rule': ParserRule(production='?', prev_classes=None, prev_tokens=None, tokens=['?'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['?']),
#    'weight': 5}),
#  (140,
#   141,
#   {'rule': ParserRule(production=u'\u2010\u090f\u2010', prev_classes=None, prev_tokens=None, tokens=['-e'], next_tokens=None, next_classes=['wb'], prev=0, next=2, match_tokens=['-e']),
#    'weight': 4}),
#  (143,
#   144,
#   {'rule': ParserRule(production=u'\u092d', prev_classes=None, prev_tokens=None, tokens=['bh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['bh']),
#    'weight': 5}),
#  (145,
#   146,
#   {'rule': ParserRule(production=u'\u091d', prev_classes=None, prev_tokens=None, tokens=['jh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['jh']),
#    'weight': 5}),
#  (148, 149, {'weight': 0}),
#  (149,
#   150,
#   {'rule': ParserRule(production=u'\u092a\u0947', prev_classes=['wb'], prev_tokens=None, tokens=['p', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['p', 'a', 'h']),
#    'weight': 3}),
#  (151,
#   152,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['_'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['_']),
#    'weight': 5}),
#  (153, 192, {'weight': 0}),
#  (153, 154, {'weight': 0}),
#  (153,
#   251,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['-'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['-']),
#    'weight': 5}),
#  (154, 155, {'weight': 0}),
#  (155,
#   156,
#   {'rule': ParserRule(production=u'\u2010\u0913\u2010', prev_classes=None, prev_tokens=None, tokens=['-', 'o', '-'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['-', 'o', '-']),
#    'weight': 5}),
#  (157,
#   165,
#   {'rule': ParserRule(production=u'\u0915', prev_classes=None, prev_tokens=None, tokens=['k'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['k']),
#    'weight': 5}),
#  (157, 158, {'weight': 0}),
#  (158, 159, {'weight': 0}),
#  (159,
#   160,
#   {'rule': ParserRule(production=u'\u0915\u093f', prev_classes=None, prev_tokens=None, tokens=['k', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=0, next=4, match_tokens=['k', 'i', 'h']),
#    'weight': 4}),
#  (163,
#   164,
#   {'rule': ParserRule(production=u'\u0917', prev_classes=None, prev_tokens=None, tokens=['g'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['g']),
#    'weight': 5}),
#  (166,
#   167,
#   {'rule': ParserRule(production=u'\u093e', prev_classes=None, prev_tokens=None, tokens=[';aa'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';aa']),
#    'weight': 5}),
#  (169,
#   170,
#   {'rule': ParserRule(production=u'\u0938', prev_classes=None, prev_tokens=None, tokens=['s'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['s']),
#    'weight': 5}),
#  (171,
#   172,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['w'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['w']),
#    'weight': 5}),
#  (174, 252, {'weight': 0}),
#  (174,
#   175,
#   {'rule': ParserRule(production=u'\u091a', prev_classes=None, prev_tokens=None, tokens=['ch'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ch']),
#    'weight': 5}),
#  (176, 177, {'weight': 0}),
#  (177,
#   178,
#   {'rule': ParserRule(production=u'\u0959\u0941', prev_classes=['wb'], prev_tokens=None, tokens=[';x', 'v', 'u'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=[';x', 'v', 'u']),
#    'weight': 4}),
#  (182,
#   183,
#   {'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['))'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['))']),
#    'weight': 5}),
#  (184, 185, {'weight': 0}),
#  (184, 281, {'weight': 0}),
#  (184, 241, {'weight': 0}),
#  (185,
#   186,
#   {'rule': ParserRule(production=u'\u0928\u0924\u0940', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'ii'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'ii']),
#    'weight': 5}),
#  (188,
#   189,
#   {'rule': ParserRule(production=u'\u091b', prev_classes=None, prev_tokens=None, tokens=['chh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['chh']),
#    'weight': 5}),
#  (190,
#   191,
#   {'rule': ParserRule(production=u'\u092b', prev_classes=None, prev_tokens=None, tokens=['ph'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['ph']),
#    'weight': 5}),
#  (192, 193, {'weight': 0}),
#  (193, 194, {'weight': 0}),
#  (193,
#   234,
#   {'rule': ParserRule(production=u'\u2010\u0939\u093e', prev_classes=None, prev_tokens=None, tokens=['-', 'h', 'aa'], next_tokens=None, next_classes=['wb'], prev=0, next=4, match_tokens=['-', 'h', 'aa']),
#    'weight': 4}),
#  (194,
#   195,
#   {'rule': ParserRule(production=u'\u2010\u0939\u093e-\u090f-', prev_classes=None, prev_tokens=None, tokens=['-', 'h', 'aa', '-e'], next_tokens=None, next_classes=['wb'], prev=0, next=5, match_tokens=['-', 'h', 'aa', '-e']),
#    'weight': 4}),
#  (196,
#   197,
#   {'rule': ParserRule(production=u'\u0914', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'au'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'au']),
#    'weight': 4}),
#  (198,
#   199,
#   {'rule': ParserRule(production=u'\u0910', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'ai'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ai']),
#    'weight': 4}),
#  (202,
#   203,
#   {'rule': ParserRule(production=u'\u0928\u094d\u0928', prev_classes=['vowel'], prev_tokens=None, tokens=['n', 'n'], next_tokens=None, next_classes=['vowel'], prev=1, next=3, match_tokens=['n', 'n']),
#    'weight': 3}),
#  (204,
#   205,
#   {'rule': ParserRule(production=u'\u0906', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'aa']),
#    'weight': 4}),
#  (207,
#   208,
#   {'rule': ParserRule(production=u'\u092c', prev_classes=None, prev_tokens=None, tokens=['b'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['b']),
#    'weight': 5}),
#  (207, 285, {'weight': 0}),
#  (209,
#   210,
#   {'rule': ParserRule(production=u'\u095e', prev_classes=None, prev_tokens=None, tokens=['f'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['f']),
#    'weight': 5}),
#  (213,
#   214,
#   {'rule': ParserRule(production=u'\u091c', prev_classes=None, prev_tokens=None, tokens=['j'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['j']),
#    'weight': 5}),
#  (217,
#   218,
#   {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=['.z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['.z']),
#    'weight': 5}),
#  (219,
#   220,
#   {'rule': ParserRule(production=u'\u0930', prev_classes=None, prev_tokens=None, tokens=['r'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['r']),
#    'weight': 5}),
#  (223,
#   224,
#   {'rule': ParserRule(production=u'\u095b', prev_classes=None, prev_tokens=None, tokens=['z'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['z']),
#    'weight': 5}),
#  (225,
#   233,
#   {'rule': ParserRule(production=u'\u0908', prev_classes=['vowel'], prev_tokens=None, tokens=['((', 'ii'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ii']),
#    'weight': 4}),
#  (225,
#   226,
#   {'rule': ParserRule(production=u'\u0908', prev_classes=['wb'], prev_tokens=None, tokens=['((', 'ii'], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=['((', 'ii']),
#    'weight': 4}),
#  (228, 229, {'weight': 0}),
#  (229,
#   230,
#   {'rule': ParserRule(production=u'\u0941\u0913\u0902', prev_classes=['consonant'], prev_tokens=None, tokens=['uu', '))', 'o', ';n'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['uu', '))', 'o', ';n']),
#    'weight': 3}),
#  (231,
#   232,
#   {'rule': ParserRule(production=u'\u0916', prev_classes=None, prev_tokens=None, tokens=['kh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['kh']),
#    'weight': 5}),
#  (241,
#   242,
#   {'rule': ParserRule(production=u'\u0928\u0924\u0947', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'e'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'e']),
#    'weight': 5}),
#  (245,
#   246,
#   {'rule': ParserRule(production=')', prev_classes=None, prev_tokens=None, tokens=[')'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[')']),
#    'weight': 5}),
#  (248, 249, {'weight': 0}),
#  (249,
#   250,
#   {'rule': ParserRule(production=u'\u0941\u0906', prev_classes=['consonant'], prev_tokens=None, tokens=['u', '((', 'aa'], next_tokens=None, next_classes=None, prev=1, next=3, match_tokens=['u', '((', 'aa']),
#    'weight': 4}),
#  (252, 253, {'weight': 0}),
#  (253,
#   254,
#   {'rule': ParserRule(production=u'\u091a\u0947', prev_classes=['consonant'], prev_tokens=None, tokens=['ch', 'i', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['ch', 'i', 'h']),
#    'weight': 3}),
#  (255,
#   256,
#   {'rule': ParserRule(production=u'\u0935\u0939\u0940', prev_classes=['wb'], prev_tokens=None, tokens=['v', 'u', 'h', 'ii'], next_tokens=None, next_classes=['wb'], prev=1, next=5, match_tokens=['v', 'u', 'h', 'ii']),
#    'weight': 3}),
#  (257, 258, {'weight': 0}),
#  (258,
#   259,
#   {'rule': ParserRule(production=u'\u0928', prev_classes=['wb'], prev_tokens=None, tokens=['n', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['n', 'a', 'h']),
#    'weight': 3}),
#  (260,
#   261,
#   {'rule': ParserRule(production=u'\u095a', prev_classes=None, prev_tokens=None, tokens=[';g'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=[';g']),
#    'weight': 5}),
#  (264,
#   265,
#   {'rule': ParserRule(production=u'\u094b', prev_classes=['consonant'], prev_tokens=None, tokens=[';o', '(('], next_tokens=None, next_classes=None, prev=1, next=2, match_tokens=[';o', '((']),
#    'weight': 4}),
#  (272,
#   273,
#   {'rule': ParserRule(production=u'\u092e', prev_classes=None, prev_tokens=None, tokens=['m'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['m']),
#    'weight': 5}),
#  (274,
#   275,
#   {'rule': ParserRule(production=u'\u0958', prev_classes=None, prev_tokens=None, tokens=['q'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['q']),
#    'weight': 5}),
#  (277,
#   278,
#   {'rule': ParserRule(production=u'\u0936', prev_classes=None, prev_tokens=None, tokens=['sh'], next_tokens=None, next_classes=None, prev=0, next=1, match_tokens=['sh']),
#    'weight': 5}),
#  (281,
#   282,
#   {'rule': ParserRule(production=u'\u0928\u0924\u093e', prev_classes=None, prev_tokens=None, tokens=['n', 't', 'aa'], next_tokens=None, next_classes=None, prev=0, next=3, match_tokens=['n', 't', 'aa']),
#    'weight': 5}),
#  (285, 286, {'weight': 0}),
#  (286,
#   287,
#   {'rule': ParserRule(production=u'\u092c', prev_classes=['wb'], prev_tokens=None, tokens=['b', 'a', 'h'], next_tokens=None, next_classes=['wb'], prev=1, next=4, match_tokens=['b', 'a', 'h']),
#    'weight': 3})]

# %%
from collections import defaultdict
out_edges = defaultdict(list)

for e in DG.edges(data=True):
    start,end,data = e
    out_edges[start].append(e)

# %%
sorted_out_edges = defaultdict(list)
for k,edges in out_edges.iteritems():
    sorted_edges = sorted(edges, key =lambda x: x[2]['weight'], reverse=True)
    sorted_out_edges[k] = sorted_edges

# %%
sorted_out_edges[2]
# Out:
# []

# %%
sorted_out_edges
# Out:
# defaultdict(<type 'list'>, {0: [(0, 1, {'weight': 0}), (0, 130, {'weight': 0}), (0, 3, {'weight': 0}), (0, 223, {'weight': 0}), (0, 5, {'weight': 0}), (0, 134, {'weight': 0}), (0, 137, {'weight': 0}), (0, 11, {'weight': 0}), (0, 140, {'weight': 0}), (0, 143, {'weight': 0}), (0, 272, {'weight': 0}), (0, 17, {'weight': 0}), (0, 274, {'weight': 0}), (0, 21, {'weight': 0}), (0, 23, {'weight': 0}), (0, 25, {'weight': 0}), (0, 27, {'weight': 0}), (0, 157, {'weight': 0}), (0, 260, {'weight': 0}), (0, 32, {'weight': 0}), (0, 34, {'weight': 0}), (0, 163, {'weight': 0}), (0, 36, {'weight': 0}), (0, 38, {'weight': 0}), (0, 40, {'weight': 0}), (0, 169, {'weight': 0}), (0, 42, {'weight': 0}), (0, 171, {'weight': 0}), (0, 45, {'weight': 0}), (0, 174, {'weight': 0}), (0, 47, {'weight': 0}), (0, 49, {'weight': 0}), (0, 51, {'weight': 0}), (0, 53, {'weight': 0}), (0, 182, {'weight': 0}), (0, 55, {'weight': 0}), (0, 57, {'weight': 0}), (0, 59, {'weight': 0}), (0, 151, {'weight': 0}), (0, 61, {'weight': 0}), (0, 190, {'weight': 0}), (0, 63, {'weight': 0}), (0, 65, {'weight': 0}), (0, 67, {'weight': 0}), (0, 69, {'weight': 0}), (0, 71, {'weight': 0}), (0, 73, {'weight': 0}), (0, 75, {'weight': 0}), (0, 219, {'weight': 0}), (0, 207, {'weight': 0}), (0, 80, {'weight': 0}), (0, 209, {'weight': 0}), (0, 82, {'weight': 0}), (0, 84, {'weight': 0}), (0, 213, {'weight': 0}), (0, 86, {'weight': 0}), (0, 89, {'weight': 0}), (0, 91, {'weight': 0}), (0, 93, {'weight': 0}), (0, 95, {'weight': 0}), (0, 97, {'weight': 0}), (0, 99, {'weight': 0}), (0, 166, {'weight': 0}), (0, 102, {'weight': 0}), (0, 145, {'weight': 0}), (0, 104, {'weight': 0}), (0, 188, {'weight': 0}), (0, 106, {'weight': 0}), (0, 231, {'weight': 0}), (0, 109, {'weight': 0}), (0, 111, {'weight': 0}), (0, 217, {'weight': 0}), (0, 115, {'weight': 0}), (0, 245, {'weight': 0}), (0, 119, {'weight': 0}), (0, 153, {'weight': 0}), (0, 122, {'weight': 0}), (0, 277, {'weight': 0})], 1: [(1, 2, {'weight': 5, 'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['\x00'], next_tokens=None, next_classes=None, prev=0, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])})], 2: [], 3: [(3, 4, {'weight': 5, 'rule': ParserRule(production=u'\u0943', prev_classes=None, prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=0, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (3, 262, {'weight': 4, 'rule': ParserRule(production=u'\u090b', prev_classes=['vowel'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (3, 247, {'weight': 4, 'rule': ParserRule(production=u'\u090b', prev_classes=['wb'], prev_tokens=None, tokens=['.ri'], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])})], 5: [(5, 266, {'weight': 5, 'rule': ParserRule(production='', prev_classes=None, prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=0, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (5, 161, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['short_vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (5, 8, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['vowel'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (5, 44, {'weight': 4, 'rule': ParserRule(production=u'\u0905', prev_classes=['wb'], prev_tokens=None, tokens=['a'], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (5, 6, {'weight': 0}), (5, 19, {'weight': 0})], 6: [(6, 147, {'weight': 4, 'rule': ParserRule(production=u'\u093e', prev_classes=['consonant'], prev_tokens=None, tokens=['a', '(('], next_tokens=None, next_classes=None, prev=12, next=6, match_tokens=['t', 'o', 'k', 'e', 'n', 's'])}), (6, 7, {'w ...

# %%
x=nagarip.rules[0]
type(x)
# Out:
# graphparser.ParserRule

# %%
x.

# %%
nagarip.dict_rules[0].get('tokens')
# Out:
# ['\x00']

# %%
nagarip.rul
